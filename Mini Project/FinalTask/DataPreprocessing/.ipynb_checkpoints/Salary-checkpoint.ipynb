# %%
import os

import pandas as pd
import numpy as np
import missingno as msno

# %%
@staticmethod
def setup_pandas_options():
    pd.set_option('display.max_columns', 1000)
    pd.set_option('display.width', 1000)
    pd.set_option('display.max_colwidth', 1000)

# %%
df= pd.read_csv('../RawData/simulated_transaction_2024.csv')
print(df.info())
print(df.shape)
print(df.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 230596 entries, 0 to 230595
# Data columns (total 7 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   Date                    230367 non-null  object
#  1   Timestamp               230345 non-null  object
#  2   Account No              230372 non-null  float64
#  3   Balance                 230350 non-null  float64
#  4   Amount                  230387 non-null  float64
#  5   Third Party Account No  6832 non-null    float64
#  6   Third Party Name        223517 non-null  object
# dtypes: float64(4), object(3)
# memory usage: 12.3+ MB
# None
# (230596, 7)
#          Date Timestamp   Account No  Balance  Amount  Third Party Account No  \
# 0  01/01/2023     00:00  678330503.0   2971.0  1584.0                     NaN
# 1  01/01/2023     00:00  472213568.0   3792.0  1950.0                     NaN
# ...

# %%
msno.matrix(df)
# Out:
# <Axes: >

# %%
salary_file_path='../RawData/Salary.csv'
db_salary = pd.read_csv(salary_file_path)

# %%
print(db_salary.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7036 entries, 0 to 7035
# Data columns (total 7 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Date                    7036 non-null   object
#  1   Timestamp               7036 non-null   object
#  2   Account No              7036 non-null   int64
#  3   Balance                 7036 non-null   float64
#  4   Amount                  7036 non-null   float64
#  5   Third Party Account No  0 non-null      float64
#  6   Third Party Name        7036 non-null   object
# dtypes: float64(3), int64(1), object(3)
# memory usage: 384.9+ KB
# None

# %%
print(db_salary.head)
# Out:
# <bound method NDFrame.head of             Date Timestamp  Account No      Balance  Amount  \
# 0     31/01/2023      0:00   101531259   427.437950  1542.5
# 1     28/02/2023      0:00   101531259   713.096750  1542.5
# 2     31/03/2023      0:00   101531259  1109.055050  1542.5
# 3     30/04/2023      0:00   101531259  1299.455700  1542.5
# 4     31/05/2023      0:00   101531259  1479.357600  1542.5
# ...          ...       ...         ...          ...     ...
# 7031  31/07/2023      0:00   999752672  2499.562844  2708.0
# 7032  31/08/2023      0:00   999752672  2691.089544  2708.0
# 7033  30/09/2023      0:00   999752672  2769.420944  2708.0
# 7034  31/10/2023      0:00   999752672  3337.786894  2708.0
# 7035  30/11/2023      0:00   999752672  3519.263894  2708.0
#
#       Third Party Account No Third Party Name
# 0                        NaN       Hobbycraft
# 1                        NaN       Hobbycraft
# 2                        NaN       Hobbycraft
# ...

# %%
grouped_data = db_salary.groupby(['Account No'])
Account_salary= grouped_data['Amount'].mean()

# %%
print(Account_salary.head())
# Out:
# Account No
# 101531259    1542.5
# 104832000    1675.0
# 106601471    1675.0
# 108481285    1584.0
# 108563213    3749.0
# Name: Amount, dtype: float64
